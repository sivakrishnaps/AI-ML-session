# %% [markdown]
# <a href="https://colab.research.google.com/github/sivakrishnaps/AI-ML-session/blob/main/pca_face_reconstruction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import fetch_lfw_people
from sklearn.decomposition import PCA as RandomizedPCA
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load dataset
faces = fetch_lfw_people(min_faces_per_person=60)

# %%
# Train PCA
pca = PCA(1100)
pca.fit(faces.data)
# Out:
# PCA(n_components=1100)

# %%
# Load image
img = Image.open('face.png').convert('L')

# %%
# Resize image
img = img.resize((47, 62))

# %%
# Convert image to array
img_array = np.array(img)

# %%
# Flatten image
img_flat = img_array.reshape(1, -1)

# %%
# Reconstruct image
components = pca.transform(img_flat)
projected = pca.inverse_transform(components)

# %%
# Plot
fig, ax = plt.subplots(1, 2, figsize=(6,3),
                       subplot_kw={'xticks':[], 'yticks':[]})

ax[0].imshow(img_array, cmap='binary_r')
ax[0].set_title('Original')

ax[1].imshow(projected.reshape(62,47), cmap='binary_r')
ax[1].set_title('Reconstructed')

plt.show()
